# %%
from visiualisation.plots import plots

# %%
# Benchmarks:
#   - qasmbench-medium
#   - qasmbench-large
#   - queko-bigd
#   - queko-bss-16qbt 
#   - queko-bss-20qbt
#   - queko-bss-53qbt
#   - queko-bss-54qbt
#   - queko-bss-81qbt

#
# Layout:
#   - Trivial
#   - default
#
# Methods:
#   - sabre
#   - qmap
#   - pytket
#   - cirq
#   - Qlosure
#
# Backends:
#   - Sherbrooke
#   - Ankaa-3

# %%
benchmark = "queko-bss-16qbt"
layout = "trivial"
beckend = "sherbrooke"
methods = ["cirq","sabre","qmap","pytket","Qlosure"]

plots(benchmark,methods,layout,beckend,our_method="Qlosure")
